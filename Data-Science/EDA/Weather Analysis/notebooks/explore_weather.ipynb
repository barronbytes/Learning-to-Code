# %% [markdown]
# # Explore Weather
#
# Create your own EDA below! Create as many code-blocks as you need.
#
# Once you've completed your EDA, complete the section titled **Reflections** where you will answer questions about your EDA.

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# import data
weather1 = pd.read_csv("../data/weather/weather_data1.csv")
weather2 = pd.read_csv("../data/weather/weather_data2.csv")

# %%
# TODO: concatenate your data files together and save to a new csv file ("../data/weather/weather_data.csv")
weather = pd.concat([weather1, weather2], ignore_index=True, sort=False)
weather.to_csv("../data/weather/weather_data.csv", sep = ',', index = False, header = True)

# %%
# TODO: view first 5 rows of your data
weather.head()
# Out:
#    year  rain_max   temp_avg   temp_max   temp_min    hum_max    hum_min  \
# 0  2006  6.670968  21.803087  27.190323  18.654839  97.129032  57.806452
# 1  2007  1.866250  23.040999  27.649375  18.753125  87.837500  48.493750
# 2  2008  3.777049  20.682400  27.000000  16.216393  96.136612  51.415301
# 3  2009  3.380220  21.023802  27.769231  16.410440  96.054945  49.329670
# 4  2010  2.183516  21.444293  28.580769  16.156044  95.247253  44.648352
#
#    wind_max  wind_avg   subdivision
# 0  9.706452  2.075207  Minas Gerais
# 1  8.749375  2.069605  Minas Gerais
# 2  8.865027  1.584408  Minas Gerais
# 3  9.114286  1.611746  Minas Gerais
# 4  9.109341  1.455907  Minas Gerais

# %%
# TODO: describe your numeric columns
weather.describe()
# Out:
#               year   rain_max   temp_avg   temp_max   temp_min    hum_max  \
# count    18.000000  18.000000  18.000000  18.000000  18.000000  18.000000
# mean   2014.500000   3.175087  21.285831  28.198312  16.458525  96.502990
# std       5.338539   1.190658   0.549483   0.564714   0.891070   2.345644
# min    2006.000000   1.617582  20.682400  27.000000  15.268681  87.837500
# 25%    2010.250000   2.342250  20.975602  27.811486  16.041470  96.079483
# 50%    2014.500000   2.978022  21.126061  28.406027  16.319722  97.089241
# 75%    2018.750000   3.718815  21.434377  28.614973  16.459066  97.553044
# max    2023.000000   6.670968  23.040999  29.010989  18.753125  98.500000
#
#          hum_min   wind_max   wind_avg
# count  18.000000  18.000000  18.000000
# mean   48.528039   8.469412   1.286295
# std     3.010135   0.611327   0.399773
# min    44.648352   7.484426   0.812202
# 25%    47.154325   7.906319   0.911424
# 50%    48.450172   8.489286   1.216155
# ...

# %%
# TODO: display the null values in your dataframe
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         18 non-null     int64
#  1   rain_max     18 non-null     float64
#  2   temp_avg     18 non-null     float64
#  3   temp_max     18 non-null     float64
#  4   temp_min     18 non-null     float64
#  5   hum_max      18 non-null     float64
#  6   hum_min      18 non-null     float64
#  7   wind_max     18 non-null     float64
#  8   wind_avg     18 non-null     float64
#  9   subdivision  18 non-null     object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.5+ KB

# %%
# TODO: BEGIN YOUR EDA!

# %% [markdown]
# ## Reflections
#
# Answer each question based on the visualizations that you've generated.
#
# Remember, you must justify your answers with proof! Look back to W6D3 for more context.

# %%
weather.plot(kind="line", x="year", y="temp_avg")
plt.xlabel("Year")
plt.ylabel("Average Temperature")
plt.title("Average Temperature vs Year")
plt.show()

# %% [markdown]
# Q1: How is average temperature changing across the years for Minas Gerais? Is this increasing or decreasing?
#
# > The figure above shows average temperature decreasing over time.

# %%
weather.plot(kind="line", x="year", y="hum_min")
plt.xlabel("Year")
plt.ylabel("Minimum Humidity")
plt.title("Minimum Humidity vs Year")
plt.show()

# %% [markdown]
# Q2: How is minimum humidity changing across the years for Minas Gerais? Is this increasing or decreasing?
#
# > The figure above shows minimum humidity decreasing over time.

# %%
weather.plot(kind="line", x="year", y="wind_avg")
plt.xlabel("Year")
plt.ylabel("Average Wind Speed")
plt.title("Average Wind Speed vs Year")
plt.show()

# %% [markdown]
# Q3: How is average wind speed changing across the years for Minas Gerais? Is this increasing or decreasing?
#
# > The figure above shows average wind speed decreasing over time.

# %%
max_rain = weather["rain_max"].max()
max_year = weather[weather["rain_max"] == max_rain].year
print(max_year)
# Out:
# 0    2006
# Name: year, dtype: int64

# %% [markdown]
# Q4: Which year had the highest maximum record rainfall?
#
# > The highest rainfall occurred once in hear 2006.

# %%
rain_humidity = weather["rain_max"].corr(weather["hum_max"])
print(rain_humidity)
# Out:
# 0.4057821680144417

# %% [markdown]
# Q5: What is the relationship between max rain and max humidity? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# > The Person coefficient of 0.41 indicates a weakly positive relationship between max rain and max humidity.

# %%
wind_temp = weather["wind_avg"].corr(weather["temp_avg"])
print(wind_temp)
# Out:
# 0.4765294973950927

# %% [markdown]
# Q6: What is the relationship between average wind speed and average temperature? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# > The Person coefficient of 0.48 indicates a weakly positive relationship between avg wind speed and avg temperature.
